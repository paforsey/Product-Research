# %%
# Install Packages

import numpy as np
import pandas as pd

# %%
# Create Tarot Cards

card_names = ['The Fool', 'The High Priestess', 'The Empress', 'The Emperor', 
                'The High Priest', 'The Lover', 'The Chariot', 'Justice', 'The Hermit', 
                'The Wheel of Fortune', 'Strength', 'The Hanged Man', 'Death', 'Temperance',
                'The Devil', 'The Tower', 'The Stars', 'The Moon', 'The Sun',
                'The Judgement', 'The World', 'The Fool']

card_numbers = ['I', 'II', 'III', 'IV', 'V', 'VI', 'VII', 'VILI', 'IX', 'X', 'XI',
                       'XII', 'XIII', 'XIV', 'XV', 'XVI', 'XVII', 'XVIII', 'XIX',
                       'XX', 'XXI', 'O']

up_position = np.repeat('up', 22)
dn_position = np.repeat('dn', 22)

major_arcana = pd.DataFrame({"card_number": card_numbers, "card_name": card_names})

#major_arcana = pd.DataFrame([card_numbers, card_names], columns=['card_number', 'card_name'])

print(major_arcana)

pd.concat([major_arcana, major_arcana])
# Out:
#    card_number             card_name
# 0            I              The Fool
# 1           II    The High Priestess
# 2          III           The Empress
# 3           IV           The Emperor
# 4            V       The High Priest
# 5           VI             The Lover
# 6          VII           The Chariot
# 7         VILI               Justice
# 8           IX            The Hermit
# 9            X  The Wheel of Fortune
# 10          XI              Strength
# 11         XII        The Hanged Man
# 12        XIII                 Death
# 13         XIV            Temperance
# 14          XV             The Devil
# 15         XVI             The Tower
# 16        XVII             The Stars
# 17       XVIII              The Moon
# 18         XIX               The Sun
# 19          XX         The Judgement
# 20         XXI             The World
# 21           O              The Fool
#    card_number             card_name
# 0            I              The Fool
# ...

# %%
# Randomly Select Tarot Cards

n = 3
random_selection = np.random.choice(major_arcana['card_name'], n, replace=False)

print(random_selection)
# Out:
# ['The Tower' 'The Stars' 'The Fool']
